# %% [markdown]
# **Import Required Libraries**

# %%
from pyspark.sql import functions as F
from delta.tables import DeltaTable

# %% [markdown]
# **Load Project Utilities & Initialize Notebook Widgets**

# %%
# %run /Workspace/consolidated_pipeline/1_setup/utilities

# %%
print(bronze_schema, silver_schema, gold_schema)
# Out:
# bronze silver gold

# %%
dbutils.widgets.text("catalog", "fmcg", "Catalog")
dbutils.widgets.text("data_source", "orders", "Data Source")

catalog = dbutils.widgets.get("catalog")
data_source = dbutils.widgets.get("data_source")

base_path = 's3://sportsbar-rh03'
landing_path = f"{base_path}/landing/"
processed_path = f"{base_path}/processed/"
print("Base Path: ", base_path)
print("Landing Path: ", landing_path)
print("Processed Path: ", processed_path)


# define the tables
bronze_table = f"{catalog}.{bronze_schema}.{data_source}"
silver_table = f"{catalog}.{silver_schema}.{data_source}"
gold_table = f"{catalog}.{gold_schema}.sb_fact_{data_source}"
# Out:
# Base Path:  s3://sportsbar-rh03
# Landing Path:  s3://sportsbar-rh03/landing/
# Processed Path:  s3://sportsbar-rh03/processed/

# %% [markdown]
# ## Bronze

# %%
df = spark.read.options(header=True, inferSchema=True).csv(f"{landing_path}/*.csv").withColumn("read_timestamp", F.current_timestamp()).select("*", "_metadata.file_name", "_metadata.file_size")

print("Total Rows: ", df.count())
df.show(5)
# Out:
# Total Rows:  51810
# +------------+--------------------+-----------+----------+---------+--------------------+--------------------+---------+
# |    order_id|order_placement_date|customer_id|product_id|order_qty|      read_timestamp|           file_name|file_size|
# +------------+--------------------+-----------+----------+---------+--------------------+--------------------+---------+
# |FOCT62720602|Tuesday, Septembe...|     ABC987|  25891301|     71.0|2026-08-16 09:46:...|orders_2025_09_30...|    41446|
# |FOCT62720602|Tuesday, Septembe...|     789720|  25891502|    125.0|2026-08-16 09:46:...|orders_2025_09_30...|    41446|
# |FOCT62720602|Tuesday, Septembe...|     789720|  25891403|    462.0|2026-08-16 09:46:...|orders_2025_09_30...|    41446|
# |FOCT62720602|Tuesday, Septembe...|    INVALID|  25891601|    133.0|2026-08-16 09:46:...|orders_2025_09_30...|    41446|
# |FOCT62720602|Tuesday, Septembe...|     789720|  25891602|     79.0|2026-08-16 09:46:...|orders_2025_09_30...|    41446|
# +------------+--------------------+-----------+----------+---------+--------------------+--------------------+---------+
# only showing top 5 rows

# %%
df.write\
 .format("delta") \
 .option("delta.enableChangeDataFeed", "true") \
 .mode("append") \
 .saveAsTable(bronze_table)

# %% [markdown]
# ### Moving files from source to processed directory

# %%
files = dbutils.fs.ls(landing_path)
for file_info in files:
    dbutils.fs.mv(
        file_info.path,
        f"{processed_path}/{file_info.name}",
        True
    )

# %% [markdown]
# ## Silver

# %%
df_orders = spark.sql(f"SELECT * FROM {bronze_table}")
df_orders.show(2)
# Out:
# +------------+--------------------+-----------+----------+---------+--------------------+--------------------+---------+
# |    order_id|order_placement_date|customer_id|product_id|order_qty|      read_timestamp|           file_name|file_size|
# +------------+--------------------+-----------+----------+---------+--------------------+--------------------+---------+
# |FJUL33320501|          2025/07/01|     789320|  25891203|    150.0|2026-08-16 09:47:...|orders_2025_07_01...|    20744|
# |FJUL33320501|          2025/07/01|     789320|  25891301|     46.0|2026-08-16 09:47:...|orders_2025_07_01...|    20744|
# +------------+--------------------+-----------+----------+---------+--------------------+--------------------+---------+
# only showing top 2 rows

# %% [markdown]
# **Transformations**

# %%
# 1. Keep only rows where order_qty is present
df_orders = df_orders.filter(F.col("order_qty").isNotNull())


# 2. Clean customer_id → keep numeric, else set to 999999
df_orders = df_orders.withColumn(
    "customer_id",
    F.when(F.col("customer_id").rlike("^[0-9]+$"), F.col("customer_id"))
     .otherwise("999999")
     .cast("string")
)

# 3. Remove weekday name from the date text
#    "Tuesday, July 01, 2025" → "July 01, 2025"
df_orders = df_orders.withColumn(
    "order_placement_date",
    F.regexp_replace(F.col("order_placement_date"), r"^[A-Za-z]+,\s*", "")
)

# 4. Parse order_placement_date using multiple possible formats
df_orders = df_orders.withColumn(
    "order_placement_date",
    F.coalesce(
        F.try_to_date("order_placement_date", "yyyy/MM/dd"),
        F.try_to_date("order_placement_date", "dd-MM-yyyy"),
        F.try_to_date("order_placement_date", "dd/MM/yyyy"),
        F.try_to_date("order_placement_date", "MMMM dd, yyyy"),
    )
)

# 5. Drop duplicates
df_orders = df_orders.dropDuplicates(["order_id", "order_placement_date", "customer_id", "product_id", "order_qty"])

# 5. convert product id to string
df_orders = df_orders.withColumn('product_id', F.col('product_id').cast('string'))

# %%
# check what's the maximum and minimum date
df_orders.agg(
    F.min("order_placement_date").alias("min_date"),
    F.max("order_placement_date").alias("max_date")
).show()
# Out:
# +----------+----------+
# |  min_date|  max_date|
# +----------+----------+
# |2025-07-01|2025-11-30|
# +----------+----------+

# %% [markdown]
# **Join with products**

# %%
df_products = spark.table("fmcg.silver.products")
df_joined = df_orders.join(df_products, on="product_id", how="inner").select(df_orders["*"], df_products["product_code"])

df_joined.show(5)
# Out:
# +------------+--------------------+-----------+----------+---------+--------------------+--------------------+---------+--------------------+
# |    order_id|order_placement_date|customer_id|product_id|order_qty|      read_timestamp|           file_name|file_size|        product_code|
# +------------+--------------------+-----------+----------+---------+--------------------+--------------------+---------+--------------------+
# |FJUL32202603|          2025-07-01|     789202|  25891103|    370.0|2026-08-16 09:47:...|orders_2025_07_01...|    20744|102628255d24304d6...|
# |FJUL33321602|          2025-07-01|     789321|  25891602|     74.0|2026-08-16 09:47:...|orders_2025_07_01...|    20744|778c2a7aa27bfdb21...|
# |FJUL34303602|          2025-07-01|     789303|  25891102|    317.0|2026-08-16 09:47:...|orders_2025_07_01...|    20744|e92c739a8d78cd6cb...|
# |FJUL34622602|          2025-07-01|     789622|  25891402|    439.0|2026-08-16 09:47:...|orders_2025_07_01...|    20744|fe5a8036be4b9a787...|
# |FJUL33402303|          2025-07-01|     789402|  25891303|     63.0|2026-08-16 09:47:...|orders_2025_07_01...|    20744|c68834ceaff15846b...|
# +------------+--------------------+-----------+----------+---------+--------------------+--------------------+---------+--------------------+
# only showing top 5 rows

# %%
if not (spark.catalog.tableExists(silver_table)):
    df_joined.write.format("delta").option(
        "delta.enableChangeDataFeed", "true"
    ).option("mergeSchema", "true").mode("overwrite").saveAsTable(silver_table)
else:
    silver_delta = DeltaTable.forName(spark, silver_table)
    silver_delta.alias("silver").merge(df_joined.alias("bronze"), "silver.order_placement_date = bronze.order_placement_date AND silver.order_id = bronze.order_id AND silver.product_code = bronze.product_code AND silver.customer_id = bronze.customer_id").whenMatchedUpdateAll().whenNotMatchedInsertAll().execute()

# %% [markdown]
# ## Gold

# %%
df_gold = spark.sql(f"SELECT order_id, order_placement_date as date, customer_id as customer_code, product_code, product_id, order_qty as sold_quantity FROM {silver_table};")

df_gold.show(2)
# Out:
# +------------+----------+-------------+--------------------+----------+-------------+
# |    order_id|      date|customer_code|        product_code|product_id|sold_quantity|
# +------------+----------+-------------+--------------------+----------+-------------+
# |FJUL32202603|2025-07-01|       789202|102628255d24304d6...|  25891103|        370.0|
# |FJUL33321602|2025-07-01|       789321|778c2a7aa27bfdb21...|  25891602|         74.0|
# +------------+----------+-------------+--------------------+----------+-------------+
# only showing top 2 rows

# %%
if not (spark.catalog.tableExists(gold_table)):
    print("creating New Table")
    df_gold.write.format("delta").option(
        "delta.enableChangeDataFeed", "true"
    ).option("mergeSchema", "true").mode("overwrite").saveAsTable(gold_table)
else:
    gold_delta = DeltaTable.forName(spark, gold_table)
    gold_delta.alias("source").merge(df_gold.alias("gold"), "source.date = gold.date AND source.order_id = gold.order_id AND source.product_code = gold.product_code AND source.customer_code = gold.customer_code").whenMatchedUpdateAll().whenNotMatchedInsertAll().execute()
# Out:
# creating New Table

# %% [markdown]
# ## Merging with Parent company

# %% [markdown]
# - Note: We want data for monthly level but child data is on daily level

# %% [markdown]
# **Full Load**

# %%
df_child = spark.sql(f"SELECT date, product_code, customer_code, sold_quantity FROM {gold_table}")
df_child.show(10)
# Out:
# +----------+--------------------+-------------+-------------+
# |      date|        product_code|customer_code|sold_quantity|
# +----------+--------------------+-------------+-------------+
# |2025-07-01|102628255d24304d6...|       789202|        370.0|
# |2025-07-01|778c2a7aa27bfdb21...|       789321|         74.0|
# |2025-07-01|e92c739a8d78cd6cb...|       789303|        317.0|
# |2025-07-01|fe5a8036be4b9a787...|       789622|        439.0|
# |2025-07-01|c68834ceaff15846b...|       789402|         63.0|
# |2025-07-01|778c2a7aa27bfdb21...|       999999|        148.0|
# |2025-07-01|778c2a7aa27bfdb21...|       789420|         76.0|
# |2025-07-01|778c2a7aa27bfdb21...|       789201|         52.0|
# |2025-07-01|e91ba9d665f90254d...|       789403|        379.0|
# |2025-07-01|889c67757ece9c973...|       789421|         99.0|
# +----------+--------------------+-------------+-------------+
# only showing top 10 rows

# %%
# %sql
-- Check details for product code: 102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268
SELECT 
    order_id,
    date,
    customer_code,
    product_code,
    product_id,
    sold_quantity
FROM fmcg.gold.sb_fact_orders
WHERE product_code = '102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268'
ORDER BY date DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>date</th><th>customer_code</th><th>product_code</th><th>product_id</th><th>sold_quantity</th></tr></thead><tbody><tr><td>FDEC81421103</td><td>2025-11-30</td><td>789421</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>353.0</td></tr><tr><td>FDEC81102501</td><td>2025-11-30</td><td>789102</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>499.0</td></tr><tr><td>FDEC83601601</td><td>2025-11-30</td><td>789601</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>273.0</td></tr><tr><td>FNOV731522103</td><td>2025-11-30</td><td>789522</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>370.0</td></tr><tr><td>FNOV731601603</td><td>2025-11-30</td><td>789601</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>345.0</td></tr><tr><td>FDEC83522401</td><td>2025-11-30</td><td>789522</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>346.0</td></tr><tr><td>FDEC82601301</td><td>2025-11-30</td><td>789601</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>377.0</td></tr><tr><td>FNOV731101601</td><td>2025-11-30</td><td>789101</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>413.0</td></tr><tr><td>FDEC81622401</td><td>2025-11-30</td><td>789622</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>442.0</td></tr><tr><td>FDEC83501603</td><td>2025-11-30</td><td>789501</td><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>25891103</td><td>473.0</td></tr></tbody></table></div>

# %%
# %sql
-- First, get a sample product code
SELECT product_code, COUNT(*) as order_count, SUM(sold_quantity) as total_quantity
FROM fmcg.gold.sb_fact_orders
GROUP BY product_code
LIMIT 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_code</th><th>order_count</th><th>total_quantity</th></tr></thead><tbody><tr><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>2375</td><td>918174.0</td></tr></tbody></table></div>

# %%
# Verify data in the fact_orders table
print(f"Checking table: {gold_table}")
print("="*80)

# 1. Total row count
total_rows = spark.sql(f"SELECT COUNT(*) as count FROM {gold_table}").collect()[0]['count']
print(f"\nTotal rows in fact table: {total_rows:,}")

# 2. Date range
date_range = spark.sql(f"""
    SELECT 
        MIN(date) as min_date,
        MAX(date) as max_date,
        COUNT(DISTINCT date) as distinct_dates
    FROM {gold_table}
""").collect()[0]
print(f"\nDate range: {date_range['min_date']} to {date_range['max_date']}")
print(f"Distinct dates: {date_range['distinct_dates']}")

# 3. Sample records
print("\nSample records:")
spark.sql(f"SELECT * FROM {gold_table} LIMIT 5").show()

# 4. Aggregated view by product
print("\nTop 5 products by total quantity:")
spark.sql(f"""
    SELECT 
        product_code,
        COUNT(*) as order_count,
        SUM(sold_quantity) as total_quantity
    FROM {gold_table}
    GROUP BY product_code
    ORDER BY total_quantity DESC
    LIMIT 5
""").show()
# Out:
# Checking table: fmcg.gold.sb_fact_orders
# ================================================================================
#
# Total rows in fact table: 40,811
#
# Date range: 2025-07-01 to 2025-11-30
# Distinct dates: 151
#
# Sample records:
# +------------+----------+-------------+--------------------+----------+-------------+
# |    order_id|      date|customer_code|        product_code|product_id|sold_quantity|
# +------------+----------+-------------+--------------------+----------+-------------+
# |FJUL32202603|2025-07-01|       789202|102628255d24304d6...|  25891103|        370.0|
# |FJUL33321602|2025-07-01|       789321|778c2a7aa27bfdb21...|  25891602|         74.0|
# |FJUL34303602|2025-07-01|       789303|e92c739a8d78cd6cb...|  25891102|        317.0|
# |FJUL34622602|2025-07-01|       789622|fe5a8036be4b9a787...|  25891402|        439.0|
# |FJUL33402303|2025-07-01|       789402|c68834ceaff15846b...|  25891303|         63.0|
# +------------+----------+-------------+--------------------+----------+-------------+
#
#
# Top 5 products by total quantity:
# +--------------------+-----------+--------------+
# |        product_code|order_count|total_quantity|
# +--------------------+-----------+--------------+
# |e92c739a8d78cd6cb...|       2395|      928341.0|
# |102628255d24304d6...|       2375|      918174.0|
# |e91ba9d665f90254d...|       2371|      915837.0|
# |fe5a8036be4b9a787...|       2403|      808316.0|
# |da6bfc596c1360ca0...|       2369|      803512.0|
# +--------------------+-----------+--------------+

# %%
df_child.count()
# Out:
# 40811

# %%
df_monthly = (
    df_child
    # 1. Get month start date (e.g., 2025-11-30 → 2025-11-01)
    .withColumn("month_start", F.trunc("date", "MM"))   # or F.date_trunc("month", "date").cast("date")

    # 2.Group at monthly grain by month_start + product_code + customer_code
    .groupBy("month_start", "product_code", "customer_code")
    .agg(
        F.sum("sold_quantity").alias("sold_quantity")
    )

    # 3. Rename month_start back to `date` to match your target schema
    .withColumnRenamed("month_start", "date")
)

df_monthly.show(5, truncate=False)
# Out:
# +----------+----------------------------------------------------------------+-------------+-------------+
# |date      |product_code                                                    |customer_code|sold_quantity|
# +----------+----------------------------------------------------------------+-------------+-------------+
# |2025-07-01|102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268|789202       |2944.0       |
# |2025-07-01|778c2a7aa27bfdb211fd5ece048de80d00fbf3d6924bd908d91054796ba16ab6|789321       |1742.0       |
# |2025-07-01|e92c739a8d78cd6cbe954648c2f9dd75ed61fcfd99b03e10dca65c3082d0728e|789303       |4929.0       |
# |2025-07-01|fe5a8036be4b9a787b7c0ae013fc752a8cfb6c55a2f7b2fd152a6380925e9c49|789622       |3810.0       |
# |2025-07-01|c68834ceaff15846bc1892c2185dc4e4f471d64fe3796b1a8ecc39a5a48c614f|789402       |960.0        |
# +----------+----------------------------------------------------------------+-------------+-------------+
# only showing top 5 rows

# %%
df_monthly.count()
# Out:
# 3060

# %%
gold_parent_delta = DeltaTable.forName(spark, f"{catalog}.{gold_schema}.fact_orders")
gold_parent_delta.alias("parent_gold").merge(df_monthly.alias("child_gold"), "parent_gold.date = child_gold.date AND parent_gold.product_code = child_gold.product_code AND parent_gold.customer_code = child_gold.customer_code").whenMatchedUpdateAll().whenNotMatchedInsertAll().execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]
